# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    # Open the PDF file
    with open(pdf_path, 'rb') as file:
        # Create a PDF reader object
        pdf_reader = PyPDF2.PdfReader(file)
        
        # Initialize a text variable to collect content
        text = ""
        
        # Iterate through each page
        for page_number in range(len(pdf_reader.pages)):
            # Extract text from the page
            page = pdf_reader.pages[page_number]
            text += page.extract_text()
        
        return text

# Use the function to extract text
pdf_path = 'pk.pdf'  # Replace with your PDF file path
extracted_text = extract_text_from_pdf(pdf_path)
print(extracted_text)
# Out:
# PRAKALYA AM
# 8248119404 | prakalyaam@gmail.com
# Data Analyst
# https://www.linkedin.com/in/priyankajha970/
#
#
#
# Objective
# I intend to be part of an organization where I can utilize my Computer Science  skills
# to collaborate  in teams for its growth, to challenge myself and develop as an
# individual so as to serve the organization better by enhancing my abilities in Data
# Analysis , Machine Learning , Cloud Services , and Data Science . My goal is to
# leverage Amazon Web Service  expe rtise to enhance data processing efficiency.
#
# Skills
#  Advanced SQL
#  HTML
#  JavaScript
#  Microsoft Applications
#  Business Analytics
#  Power BI
#  Tubule
#  Python
#  Data Extraction
#  Data Manipulation
#  Dashboarding
#
# Education
#  Master of Computer Applications
#                      CGPA: 93%
#               SRM Institute of Science & Technology.
#
#  Bachelor of Computer Applications
#                       CGPA: 80%
#               SRM Institute of Science & Technology.
#
#  Data Science & Data Analytics                     2024 -currently pursuing
#                Imarticus Learning
#
# Academic Projects
# Title: Prison Management System
# Organization: SRM Institute of Science and Technology
# Tenure: December 2018 -March 2019
#
# Title: Sentiment Analysis
# Organization: SRM Institute of Science and Technology
# Tenure: December 2020 -March 2021
#
# Key Metric : Utilized a strong logical approach  to monitor  and maintain  the
# performance of datasets throughout project development and effectively handled
# problem solving  tasks throug h automated report  generation using SQL queries .
# Also implemented automation  techniques to streamline the data workflow.
#
# Certifications
#  Marketing in a Digital World in COURSERA
#  Digital Analytics for Marketing Professionals: Marketing Analytics in Practice
# in COURSERA
# Languages
# English, Tamil, Malayalam.
# Personality Traits
# Good Communication, Quality Conscious, Attention to detail, Quick Study, Not Afraid
# to take initiative and speak up.
# Hobbies
# Cooking, Listening Music, Watching Movies, Swimming & Travelling
# Declaration
# I, Prakalya, do hereby declare that all the above information furnished by me are true
# to the best of my knowledge and belief.
# Signature
# Prakalya AM
